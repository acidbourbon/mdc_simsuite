# %%
import ROOT

c = ROOT.TCanvas("myCanvasName","The Canvas Title",640,480)

f = ROOT.TFile("../ana_signals_100k_gain1.4e5.root")
tree = f.Get("scope_data_tree")

tree.Draw("tot_a:t1_a >> potato(500,0,500e-9,500,0,500e-9)","","colz")
potato = f.Get("potato")
potato.SetTitle("potato")
potato.GetXaxis().SetTitle("t1 (s)")
potato.GetYaxis().SetTitle("tot (s)")
potato.Draw("colz")
c.Draw()
# Out:
# Welcome to JupyROOT 6.18/02

# %%
tree.Draw("tot_a")
c.Draw()

# %%
tree.Draw("t1_a")
c.Draw()

# %%
tree.Draw("t1_b-t1_a:t1_a+t1_b>>dummy(250,0,250e-9,200,-100e-9,100e-9)","","colz")
c.Draw()

# %%
tree.Draw("t1_a*1e9:track_start_y*1e3>>Vcurve(60,-3,3,100,0,100)","","colz")
c.Draw()

# %%
tree.Draw("tot_a*1e9:t1_a*1e9>>potato_slice(150,0,150,400,0,800)",
          "track_start_y>1.1e-3 && track_start_y<1.4e-3",
          "colz")
c.Draw()
